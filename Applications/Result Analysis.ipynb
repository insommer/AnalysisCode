# %%
cd ..
# Out:
# C:\Users\Sommer Lab\Documents\Analysis Code

# %%
import sys
# sys.path.append(r'C:\Users\Sommer Lab\Documents\Analysis Code')
import os

# from ImageAnalysis import ImageAnalysisCode
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from ImageAnalysis import ImageAnalysisCode

# %%
folderName = r'Z:\ats317group\Data\ODT Data 11.22'
fileNames = os.listdir(folderName)
# fileNames = ['ODT Position 1 Bias Scan_Oct10.csv',
#             'ODT Position 1 Bias Scan_Oct12.csv']

df = []
for f in fileNames:
    if '.csv' in f:
        dataCSV_filePath = os.path.join(folderName, f)
        df.append(pd.read_csv(dataCSV_filePath))

df = pd.concat(df)
df.time = pd.to_datetime(df.time)
df.set_index('time', inplace=True)

# df = df.loc[ 
#     (df.index>=datetime.datetime.strptime('10/1/2023', '%m/%d/%Y'))
#     &
#     (df.index<=datetime.datetime.strptime('10/23/2023', '%m/%d/%Y'))
# ]

# %%
df
# Out:
#                                                   Folder      Ycenter  \
# time
# 2023-11-22 14:38:00  Andor/ODT_P5_bias_scan_CMOT_burntin  6978.072763
# 2023-11-22 14:52:00  Andor/ODT_P5_bias_scan_CMOT_burntin  6971.943832
# 2023-11-22 14:52:00  Andor/ODT_P5_bias_scan_CMOT_burntin  7043.024961
# 2023-11-22 14:53:00  Andor/ODT_P5_bias_scan_CMOT_burntin  7102.624822
# 2023-11-22 14:53:00  Andor/ODT_P5_bias_scan_CMOT_burntin  6997.090607
# ...                                                  ...          ...
# 2023-11-22 14:29:00               Andor/ODT_P5_bias_scan  2721.820582
# 2023-11-22 14:30:00               Andor/ODT_P5_bias_scan  2722.440183
# 2023-11-22 14:30:00               Andor/ODT_P5_bias_scan  2721.435197
# 2023-11-22 14:30:00               Andor/ODT_P5_bias_scan  2722.068626
# 2023-11-22 14:30:00               Andor/ODT_P5_bias_scan  2721.174803
#
#                           Ywidth    AtomNumber      Xcenter       Xwidth  \
# time
# 2023-11-22 14:38:00  1661.929299  1.814818e+08  9410.562975  3690.670054
# 2023-11-22 14:52:00  1689.426005  1.805419e+08  9257.855599  3769.138978
# 2023-11-22 14:52:00  1622.228904  1.563194e+08  9197.016957  3398.471657
# 2023-11-22 14:53:00  1614.068984  1.363868e+08  9113.245490  3231.864633
# 2023-11-22 14:53:00  1639.539637  1.591513e+08  8922.424071  3266.364579
# ...                          ...           ...          ...          ...
# 2023-11-22 14:29:00    40.214232  1.081968e+05  1621.329661   126.320776
# 2023-11-22 14:30:00    39.189808  1.067453e+05  1653.676169   159.505427
# 2023-11-22 14:30:00    38.695651  1.051382e+05  -681.705080     8.522770
# 2023-11-22 14:30:00    39.184353  1.084776e+05  1616.296765   119.772824
# 2023-11-22 14:30:00    41.133728  1.026037e+05   344.542243    17.841534
#
#                       AtomNumberX  IterationNum  IterationCount  wait  ...  \
# time                                                                   ...
# 2023-11-22 14:38:00  1.895304e+08             0               9     2  ...
# 2023-11-22 14:52:00  2.256705e+08             0               9     2  ...
# 2023-11-22 14:52:00  1.775719e+08             1               9     2  ...
# 2023-11-22 14:53:00  1.523625e+08             2               9     2  ...
# 2023-11-22 14:53:00  1.743785e+08             3               9     2  ...
# ...                           ...           ...             ...   ...  ...
# 2023-11-22 14:29:00  1.524821e+04             4               9    30  ...
# 2023-11-22 14:30:00  2.106899e+04             5               9    30  ...
# 2023-11-22 14:30:00 -2.373070e+01             6               9    30  ...
# 2023-11-22 14:30:00  1.208867e+04             7               9    30  ...
# 2023-11-22 14:30:00  7.495453e+01             8               9    30  ...
#
#                      CamBiasCurrent  VerticalBiasCurrent  ZSBiasVoltage  \
# time
# 2023-11-22 14:38:00               0                  2.0           1.26
# 2023-11-22 14:52:00               0                  2.0           1.26
# 2023-11-22 14:52:00               0                  2.5           1.26
# 2023-11-22 14:53:00               0                  3.0           1.26
# 2023-11-22 14:53:00               0                  2.0           1.35
# ...                             ...                  ...            ...
# 2023-11-22 14:29:00               0                  2.5           1.35
# 2023-11-22 14:30:00               0                  3.0           1.35
# 2023-11-22 14:30:00               0                  2.0           1.44
# 2023-11-22 14:30:00               0                  2.5           1.44
# 2023-11-22 14:30:00               0                  3.0           1.44
#
#                      CamBiasVoltage  VerticalBiasVoltage  HighServo1  \
# time
# 2023-11-22 14:38:00           0.322               0.7390        -0.1
# 2023-11-22 14:52:00           0.322               0.7390        -0.1
# 2023-11-22 14:52:00           0.322               0.8295        -0.1
# 2023-11-22 14:53:00           0.322               0.9200        -0.1
# 2023-11-22 14:53:00           0.322               0.7390        -0.1
# ...                             ...                  ...         ...
# 2023-11-22 14:29:00           0.322               0.8295         2.2
# 2023-11-22 14:30:00           0.322               0.9200         2.2
# 2023-11-22 14:30:00           0.322               0.7390         2.2
# 2023-11-22 14:30:00           0.322               0.8295         2.2
# 2023-11-22 14:30:00           0.322               0.9200         2.2
#
#                      LowServo1  D1Time_ms  ODT_Position  Burnt_In
# time
# 2023-11-22 14:38:00          0        1.5            99         1
# 2023-11-22 14:52:00          0        1.5            99         1
# 2023-11-22 14:52:00          0        1.5            99         1
# 2023-11-22 14:53:00          0        1.5            99         1
# 2023-11-22 14:53:00          0        1.5            99         1
# ...                        ...        ...           ...       ...
# 2023-11-22 14:29:00          0        1.5             1         0
# 2023-11-22 14:30:00          0        1.5             1         0
# 2023-11-22 14:30:00          0        1.5             1         0
# 2023-11-22 14:30:00          0        1.5             1         0
# 2023-11-22 14:30:00          0        1.5             1         0
#
# [65 rows x 33 columns]

# %%
ImageAnalysisCode.PlotFromDataCSV(df, 'ZSBiasCurrent', 'AtomNumber', 
                                  iterateVariable='VerticalBiasCurrent', 
                                  filterByAnd=[
                                      'AtomNumber<1000000', 
#                                       'VerticalBiasCurrent>=7.5',
#                                       'wait==30',
                                      'ODT_Position==1'
                                  ],
                                  groupbyX=1, threeD=0,
                                 viewElev=20, viewAzim=-20
                                 )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# (<Figure size 720x576 with 1 Axes>,
#  <AxesSubplot:xlabel='ZSBiasCurrent', ylabel='AtomNumber'>)

# %%
X = 'VerticalBiasCurrent'
Y = 'ZSBiasCurrent'
Z = 'AtomNumber'
P = 'ODT_Position'
B = 'Burnt_In'

# %%
df1 = df[[X, Y, Z, P, B]]

# %%
dfODT = df1[df1.ODT_Position == 1]
dfCMOT = df1[(df1.ODT_Position == 99) & (df1.Burnt_In == 0)]
dfCMOTBurntIn = df1[(df1.ODT_Position == 99) & (df1.Burnt_In == 1)]

# %%
dfCMOTBurntIn
# Out:
#                      VerticalBiasCurrent  ZSBiasCurrent   AtomNumber  \
# time
# 2023-11-22 14:38:00                  2.0            5.0  181481783.9
# 2023-11-22 14:52:00                  2.0            5.0  180541877.6
# 2023-11-22 14:52:00                  2.5            5.0  156319370.4
# 2023-11-22 14:53:00                  3.0            5.0  136386849.8
# 2023-11-22 14:53:00                  2.0            5.5  159151265.1
# 2023-11-22 14:53:00                  2.5            5.5  140148990.0
# 2023-11-22 14:53:00                  3.0            5.5  122457453.6
# 2023-11-22 14:53:00                  2.0            6.0  140990811.7
# 2023-11-22 14:54:00                  2.5            6.0  126662824.3
# 2023-11-22 14:54:00                  3.0            6.0  110951602.6
# 2023-11-22 14:55:00                  2.0            5.0  174405931.8
# 2023-11-22 14:55:00                  2.5            5.0  155614551.3
# 2023-11-22 14:56:00                  3.0            5.0  138737550.3
# 2023-11-22 14:56:00                  2.0            5.5  162703422.8
# 2023-11-22 14:56:00                  2.5            5.5  143832293.7
# 2023-11-22 14:56:00                  3.0            5.5  124532969.3
# 2023-11-22 14:56:00                  2.0            6.0  144014631.7
# 2023-11-22 14:57:00                  2.5            6.0  123807520.6
# 2023-11-22 14:57:00                  3.0            6.0  108733152.6
#
#                      ODT_Position  Burnt_In
# time
# 2023-11-22 14:38:00            99         1
# 2023-11-22 14:52:00            99         1
# 2023-11-22 14:52:00            99         1
# 2023-11-22 14:53:00            99         1
# 2023-11-22 14:53:00            99         1
# 2023-11-22 14:53:00            99         1
# 2023-11-22 14:53:00            99         1
# 2023-11-22 14:53:00            99         1
# 2023-11-22 14:54:00            99         1
# 2023-11-22 14:54:00            99         1
# 2023-11-22 14:55:00            99         1
# 2023-11-22 14:55:00            99         1
# 2023-11-22 14:56:00            99         1
# 2023-11-22 14:56:00            99         1
# 2023-11-22 14:56:00            99         1
# 2023-11-22 14:56:00            99         1
# 2023-11-22 14:56:00            99         1
# 2023-11-22 14:57:00            99         1
# 2023-11-22 14:57:00            99         1

# %%
AtomNumCMOTB = dfCMOTBurntIn.groupby([X, Y]).mean()
AtomNumCMOTB
# Out:
#                                      AtomNumber  ODT_Position  Burnt_In
# VerticalBiasCurrent ZSBiasCurrent
# 2.0                 5.0            1.788099e+08          99.0       1.0
#                     5.5            1.609273e+08          99.0       1.0
#                     6.0            1.425027e+08          99.0       1.0
# 2.5                 5.0            1.559670e+08          99.0       1.0
#                     5.5            1.419906e+08          99.0       1.0
#                     6.0            1.252352e+08          99.0       1.0
# 3.0                 5.0            1.375622e+08          99.0       1.0
#                     5.5            1.234952e+08          99.0       1.0
#                     6.0            1.098424e+08          99.0       1.0

# %%
AtomNumCMOTB['AtomNumber'].unstack()
# Out:
# ZSBiasCurrent                 5.0           5.5           6.0
# VerticalBiasCurrent
# 2.0                  1.788099e+08  1.609273e+08  1.425027e+08
# 2.5                  1.559670e+08  1.419906e+08  1.252352e+08
# 3.0                  1.375622e+08  1.234952e+08  1.098424e+08

# %%
AtomNumCMOTB.AtomNumber.unstack()
# Out:
# ZSBiasCurrent                 5.0           5.5           6.0
# VerticalBiasCurrent
# 2.0                  1.788099e+08  1.609273e+08  1.425027e+08
# 2.5                  1.559670e+08  1.419906e+08  1.252352e+08
# 3.0                  1.375622e+08  1.234952e+08  1.098424e+08

# %%
df1mean = df1.groupby([X, Y, B, P]).mean()
df1mean
# Out:
#                                                            AtomNumber
# VerticalBiasCurrent ZSBiasCurrent Burnt_In ODT_Position
# 0.5                 6.0           0        1             5.704378e+04
# 1.0                 6.0           0        1             7.695396e+04
# 1.5                 6.0           0        1             9.710268e+04
# 2.0                 5.0           0        1             8.042547e+04
#                                            99            1.747271e+08
#                                   1        99            1.788099e+08
#                     5.5           0        1             1.085803e+05
#                                            99            1.632249e+08
#                                   1        99            1.609273e+08
#                     6.0           0        1             1.056657e+05
#                                            99            1.486031e+08
#                                   1        99            1.425027e+08
# 2.5                 4.0           0        1             3.191924e+04
#                     4.5           0        1             5.895694e+04
#                     5.0           0        1             9.103566e+04
#                                            99            1.611399e+08
#                                   1        99            1.559670e+08
#                     5.5           0        1             1.127150e+05
#                                            99            1.458190e+08
#                                   1        99            1.419906e+08
#                     6.0           0        1             1.094236e+05
#                                            99            1.321741e+08
#                                   1        99            1.252352e+08
#                     6.5           0        1             9.901554e+04
#                     7.0           0        1             8.227502e+04
# 3.0                 5.0           0        1             9.943082e+04
#                                            99            1.426544e+08
#                                   1        99            1.375622e+08
#                     5.5           0        1             1.080704e+05
#                                            99            1.282929e+08
#                                   1        99            1.234952e+08
#                     6.0           0        1             1.070030e+05
#                                            99            1.157584e+08
#                                   1        99            1.098424e+08
# 3.5                 6.0           0        1             1.061811e+05
# 4.0                 6.0           0        1             9.271010e+04
# 4.5                 6.0           0        1             8.824788e+04
# 5.0                 6.0           0        1             7.652472e+04

# %%
df1mean.AtomNumber.unstack().unstack()
# Out:
# ODT_Position                                  1                99  \
# Burnt_In                                       0   1            0
# VerticalBiasCurrent ZSBiasCurrent
# 0.5                 6.0             57043.782080 NaN          NaN
# 1.0                 6.0             76953.958245 NaN          NaN
# 1.5                 6.0             97102.682050 NaN          NaN
# 2.0                 5.0             80425.473000 NaN  174727122.5
#                     5.5            108580.252600 NaN  163224850.8
#                     6.0            105665.709333 NaN  148603064.5
# 2.5                 4.0             31919.239900 NaN          NaN
#                     4.5             58956.944010 NaN          NaN
#                     5.0             91035.657563 NaN  161139946.3
#                     5.5            112715.044667 NaN  145819010.1
#                     6.0            109423.640050 NaN  132174094.4
#                     6.5             99015.541340 NaN          NaN
#                     7.0             82275.017330 NaN          NaN
# 3.0                 5.0             99430.815195 NaN  142654393.0
#                     5.5            108070.438400 NaN  128292890.4
#                     6.0            107003.022333 NaN  115758411.7
# 3.5                 6.0            106181.053700 NaN          NaN
# 4.0                 6.0             92710.103480 NaN          NaN
# 4.5                 6.0             88247.882740 NaN          NaN
# 5.0                 6.0             76524.723570 NaN          NaN
#
# ODT_Position
# Burnt_In                                      1
# VerticalBiasCurrent ZSBiasCurrent
# 0.5                 6.0                     NaN
# 1.0                 6.0                     NaN
# 1.5                 6.0                     NaN
# 2.0                 5.0            1.788099e+08
#                     5.5            1.609273e+08
#                     6.0            1.425027e+08
# 2.5                 4.0                     NaN
#                     4.5                     NaN
#                     5.0            1.559670e+08
#                     5.5            1.419906e+08
#                     6.0            1.252352e+08
#                     6.5                     NaN
#                     7.0                     NaN
# 3.0                 5.0            1.375622e+08
#                     5.5            1.234952e+08
#                     6.0            1.098424e+08
# 3.5                 6.0                     NaN
# 4.0                 6.0                     NaN
# 4.5                 6.0                     NaN
# 5.0                 6.0                     NaN

# %%
ANO = df1mean.AtomNumber.unstack().unstack()[1][0].unstack()
ANC = df1mean.AtomNumber.unstack().unstack()[99][0].unstack()
ANCB = df1mean.AtomNumber.unstack().unstack()[99][1].unstack()

# %%
ANCB
# Out:
# ZSBiasCurrent        4.0  4.5           5.0           5.5           6.0  6.5  \
# VerticalBiasCurrent
# 0.5                  NaN  NaN           NaN           NaN           NaN  NaN
# 1.0                  NaN  NaN           NaN           NaN           NaN  NaN
# 1.5                  NaN  NaN           NaN           NaN           NaN  NaN
# 2.0                  NaN  NaN  1.788099e+08  1.609273e+08  1.425027e+08  NaN
# 2.5                  NaN  NaN  1.559670e+08  1.419906e+08  1.252352e+08  NaN
# 3.0                  NaN  NaN  1.375622e+08  1.234952e+08  1.098424e+08  NaN
# 3.5                  NaN  NaN           NaN           NaN           NaN  NaN
# 4.0                  NaN  NaN           NaN           NaN           NaN  NaN
# 4.5                  NaN  NaN           NaN           NaN           NaN  NaN
# 5.0                  NaN  NaN           NaN           NaN           NaN  NaN
#
# ZSBiasCurrent        7.0
# VerticalBiasCurrent
# 0.5                  NaN
# 1.0                  NaN
# 1.5                  NaN
# 2.0                  NaN
# 2.5                  NaN
# 3.0                  NaN
# 3.5                  NaN
# 4.0                  NaN
# 4.5                  NaN
# 5.0                  NaN

# %%
ANO
# Out:
# ZSBiasCurrent               4.0          4.5           5.0            5.5  \
# VerticalBiasCurrent
# 0.5                         NaN          NaN           NaN            NaN
# 1.0                         NaN          NaN           NaN            NaN
# 1.5                         NaN          NaN           NaN            NaN
# 2.0                         NaN          NaN  80425.473000  108580.252600
# 2.5                  31919.2399  58956.94401  91035.657563  112715.044667
# 3.0                         NaN          NaN  99430.815195  108070.438400
# 3.5                         NaN          NaN           NaN            NaN
# 4.0                         NaN          NaN           NaN            NaN
# 4.5                         NaN          NaN           NaN            NaN
# 5.0                         NaN          NaN           NaN            NaN
#
# ZSBiasCurrent                  6.0          6.5          7.0
# VerticalBiasCurrent
# 0.5                   57043.782080          NaN          NaN
# 1.0                   76953.958245          NaN          NaN
# 1.5                   97102.682050          NaN          NaN
# 2.0                  105665.709333          NaN          NaN
# 2.5                  109423.640050  99015.54134  82275.01733
# 3.0                  107003.022333          NaN          NaN
# 3.5                  106181.053700          NaN          NaN
# 4.0                   92710.103480          NaN          NaN
# 4.5                   88247.882740          NaN          NaN
# 5.0                   76524.723570          NaN          NaN

# %%
ANO.values / ANC.values
# Out:
# array([[       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan, 0.00046029, 0.00066522, 0.00071106,
#                nan,        nan],
#        [       nan,        nan, 0.00056495, 0.00077298, 0.00082788,
#                nan,        nan],
#        [       nan,        nan, 0.000697  , 0.00084237, 0.00092436,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])

# %%
ANO.values / ANCB.values
# Out:
# array([[       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan, 0.00044978, 0.00067472, 0.0007415 ,
#                nan,        nan],
#        [       nan,        nan, 0.00058369, 0.00079382, 0.00087375,
#                nan,        nan],
#        [       nan,        nan, 0.00072281, 0.0008751 , 0.00097415,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])

# %%
df1mean.index.get_level_values(1).max()
# Out:
# 7.5

# %%
scanResults = pd.read_csv(r'Z:\ats317group\Data\Analysis Resutls in csv\No ODT Bias Scan_Oct24.csv').set_index(['VerticalBiasCurrent','ZSBiasCurrent'])

# %%
scanResults
# Out:
#                                                          time  \
# VerticalBiasCurrent ZSBiasCurrent
# 0.0                 5.50           2023-10-24 20:27:53.301462
#                     5.75           2023-10-24 20:27:59.561511
#                     6.00           2023-10-24 20:28:05.821561
#                     6.25           2023-10-24 20:28:12.113610
#                     6.50           2023-10-24 20:28:18.501661
# ...                                                       ...
# 5.1                 9.00           2023-10-24 22:09:21.649012
# 5.2                 9.00           2023-10-24 22:09:28.121062
# 5.4                 9.00           2023-10-24 22:09:34.473111
# 5.5                 9.00           2023-10-24 22:09:40.769161
# 5.9                 9.00           2023-10-24 22:09:47.077209
#
#                                                      Folder      Ycenter  \
# VerticalBiasCurrent ZSBiasCurrent
# 0.0                 5.50             Andor/No_ODT_Bias_Scan  5939.850416
#                     5.75             Andor/No_ODT_Bias_Scan  5934.278433
#                     6.00             Andor/No_ODT_Bias_Scan  5908.918574
#                     6.25             Andor/No_ODT_Bias_Scan  5894.596411
#                     6.50             Andor/No_ODT_Bias_Scan  5811.243102
# ...                                                     ...          ...
# 5.1                 9.00           Andor/No_ODT_Bias_Scan_3  5646.925027
# 5.2                 9.00           Andor/No_ODT_Bias_Scan_3  5644.227673
# 5.4                 9.00           Andor/No_ODT_Bias_Scan_3  5671.850193
# 5.5                 9.00           Andor/No_ODT_Bias_Scan_3  5682.584042
# 5.9                 9.00           Andor/No_ODT_Bias_Scan_3  5732.326486
#
#                                         Ywidth    AtomNumber      Xcenter  \
# VerticalBiasCurrent ZSBiasCurrent
# 0.0                 5.50           1164.130590  6.102390e+07  6902.355185
#                     5.75           1151.799521  7.645788e+07  6852.916032
#                     6.00           1122.104213  9.394604e+07  6785.915735
#                     6.25           1124.533444  9.903443e+07  6767.746656
#                     6.50           1084.704545  1.061527e+08  6651.641469
# ...                                        ...           ...          ...
# 5.1                 9.00           1117.924269  2.030815e+07  4403.370494
# 5.2                 9.00           1128.487233  1.988842e+07  4372.914416
# 5.4                 9.00           1136.642395  1.888036e+07  4348.166831
# 5.5                 9.00           1128.862358  1.810341e+07  4353.036569
# 5.9                 9.00           1135.901871  1.582870e+07  4341.753120
#
#                                         Xwidth   AtomNumberX  IterationNum  \
# VerticalBiasCurrent ZSBiasCurrent
# 0.0                 5.50           1293.507014  6.414900e+07           0.0
#                     5.75           1420.448523  7.883618e+07           1.0
#                     6.00           1619.375959  9.457088e+07           2.0
#                     6.25           1733.890296  9.750266e+07           3.0
#                     6.50           1817.906616  1.035556e+08           4.0
# ...                                        ...           ...           ...
# 5.1                 9.00           1228.523035  2.109892e+07         121.0
# 5.2                 9.00           1324.427136  2.218923e+07         122.0
# 5.4                 9.00           1277.234157  2.041247e+07         123.0
# 5.5                 9.00           1301.993609  2.010067e+07         124.0
# 5.9                 9.00           1312.419050  1.800717e+07         125.0
#
#                                    IterationCount  ...  cMOT_coil  \
# VerticalBiasCurrent ZSBiasCurrent                  ...
# 0.0                 5.50                     99.0  ...       0.45
#                     5.75                     99.0  ...       0.45
#                     6.00                     99.0  ...       0.45
#                     6.25                     99.0  ...       0.45
#                     6.50                     99.0  ...       0.45
# ...                                           ...  ...        ...
# 5.1                 9.00                    126.0  ...       0.45
# 5.2                 9.00                    126.0  ...       0.45
# 5.4                 9.00                    126.0  ...       0.45
# 5.5                 9.00                    126.0  ...       0.45
# 5.9                 9.00                    126.0  ...       0.45
#
#                                    cMOT_dwell_ms  CamBiasCurrent  \
# VerticalBiasCurrent ZSBiasCurrent
# 0.0                 5.50                     2.0             0.0
#                     5.75                     2.0             0.0
#                     6.00                     2.0             0.0
#                     6.25                     2.0             0.0
#                     6.50                     2.0             0.0
# ...                                          ...             ...
# 5.1                 9.00                     2.0             0.0
# 5.2                 9.00                     2.0             0.0
# 5.4                 9.00                     2.0             0.0
# 5.5                 9.00                     2.0             0.0
# 5.9                 9.00                     2.0             0.0
#
#                                    ZSBiasVoltage  CamBiasVoltage  \
# VerticalBiasCurrent ZSBiasCurrent
# 0.0                 5.50                   1.350           0.322
#                     5.75                   1.395           0.322
#                     6.00                   1.440           0.322
#                     6.25                   1.485           0.322
#                     6.50                   1.530           0.322
# ...                                          ...             ...
# 5.1                 9.00                   1.980           0.322
# 5.2                 9.00                   1.980           0.322
# 5.4                 9.00                   1.980           0.322
# 5.5                 9.00                   1.980           0.322
# 5.9                 9.00                   1.980           0.322
#
#                                    VerticalBiasVoltage  HighServo1  LowServo1  \
# VerticalBiasCurrent ZSBiasCurrent
# 0.0                 5.50                        0.3770         2.2        0.0
#                     5.75                        0.3770         2.2        0.0
#                     6.00                        0.3770         2.2        0.0
#                     6.25                        0.3770         2.2        0.0
#                     6.50                        0.3770         2.2        0.0
# ...                                                ...         ...        ...
# 5.1                 9.00                        1.3001         2.2        0.0
# 5.2                 9.00                        1.3182         2.2        0.0
# 5.4                 9.00                        1.3544         2.2        0.0
# 5.5                 9.00                        1.3725         2.2        0.0
# 5.9                 9.00                        1.4449         2.2        0.0
#
#                                    D1Time_ms  ODT_Position
# VerticalBiasCurrent ZSBiasCurrent
# 0.0                 5.50                 1.5           9.0
#                     5.75                 1.5           9.0
#                     6.00                 1.5           9.0
#                     6.25                 1.5           9.0
#                     6.50                 1.5           9.0
# ...                                      ...           ...
# 5.1                 9.00                 1.5           9.0
# 5.2                 9.00                 1.5           9.0
# 5.4                 9.00                 1.5           9.0
# 5.5                 9.00                 1.5           9.0
# 5.9                 9.00                 1.5           9.0
#
# [425 rows x 31 columns]

# %%
scanResults.index.unique()
# Out:
# MultiIndex([(0.0,  5.5),
#             (0.0, 5.75),
#             (0.0,  6.0),
#             (0.0, 6.25),
#             (0.0,  6.5),
#             (0.0, 6.55),
#             (0.0,  6.6),
#             (0.0, 6.65),
#             (0.0,  6.7),
#             (0.0, 6.75),
#             ...
#             (4.4,  9.0),
#             (4.6,  9.0),
#             (4.7,  9.0),
#             (4.8,  9.0),
#             (5.0,  9.0),
#             (5.1,  9.0),
#             (5.2,  9.0),
#             (5.4,  9.0),
#             (5.5,  9.0),
#             (5.9,  9.0)],
#            names=['VerticalBiasCurrent', 'ZSBiasCurrent'], length=417)

# %%
df1mean.idxmax()
# Out:
# ODT_Position
# 1.0     (0.5, 6.75)
# 5.0      (1.8, 6.4)
# 9.0      (4.7, 5.7)
# 11.0     (7.8, 4.8)
# 99.0     (4.4, 5.8)
# dtype: object

# %%
df1mean.max()
# Out:
# ODT_Position
# 1.0     2.042041e+05
# 5.0     2.548437e+05
# 9.0     2.124775e+05
# 11.0    1.387646e+05
# 99.0    1.015988e+08
# dtype: float64

# %%
df1mean[[99]].loc[df1mean.idxmax()]
# Out:
# ODT_Position                               99.0
# VerticalBiasCurrent ZSBiasCurrent
# 0.5                 6.75                    NaN
# 1.8                 6.40                    NaN
# 4.7                 5.70           9.833773e+07
# 7.8                 4.80           5.048771e+07
# 4.4                 5.80           1.015988e+08

# %%
df1std = df1.groupby([X, Y, P]).std().AtomNumber.unstack()

# %%
df1std.loc[df1mean.idxmax()]
# Out:
# ODT_Position                               1.0           5.0          9.0   \
# VerticalBiasCurrent ZSBiasCurrent
# 0.5                 6.75           22850.116045           NaN          NaN
# 1.8                 6.40                    NaN  16541.322479          NaN
# 4.7                 5.70                    NaN           NaN  7865.773675
# 7.8                 4.80                    NaN           NaN          NaN
# 4.4                 5.80                    NaN           NaN          NaN
#
# ODT_Position                               11.0          99.0
# VerticalBiasCurrent ZSBiasCurrent
# 0.5                 6.75                    NaN           NaN
# 1.8                 6.40                    NaN           NaN
# 4.7                 5.70                    NaN  2.041578e+06
# 7.8                 4.80           16579.809849  6.222847e+05
# 4.4                 5.80                    NaN  1.915187e+06

# %%
df1mean.index.get_level_values(1)
# Out:
# Float64Index([ 5.5, 5.75,  6.0, 6.25,  6.5, 6.55,  6.6, 6.65,  6.7, 6.75,
#               ...
#                4.4,  4.6,  4.7,  4.8,  5.0,  5.1,  5.2,  5.4,  5.5,  5.9],
#              dtype='float64', name='ZSBiasCurrent', length=425)

# %%
df1mean.to_csv('df1mean.csv')

# %%
pwd
# Out:
# 'C:\\Users\\Sommer Lab\\Documents\\Analysis Code'

# %%
totalDataPath =r"Z:\ats317group\Data"
date = '10/10/2023'

# %%
dataCSV_filename = 'cMOT 0.2 and 0.45 with different bias.csv'

dayFolderPath = ImageAnalysisCode.GetDataLocation(date, DataPath=totalDataPath)
dataCSV_filePath = os.path.join(dayFolderPath, dataCSV_filename)

# %%
ImageAnalysisCode.PlotFromDataCSV(dataCSV_filePath, 'VerticalBiasCurrent', 'Ycenter', iterateVariable='cMOT_coil')

# %%
dataCSV_filename = 'ODT Move.csv'

dayFolderPath = ImageAnalysisCode.GetDataLocation(date, DataPath=totalDataPath)
dataCSV_filePath = os.path.join(dayFolderPath, dataCSV_filename)

# %%
PlotFromDataCSV(dataCSV_filePath, 
                                  'wait', 'AtomNumber', 
                                  iterateVariable=None, filterlist=['wait==30'], groupby='wait')
# Out:
#                        time            Folder   Ycenter    Ywidth  \
# 2   2023-10-10 13:25:27.750               NaN       NaN       NaN
# 5   2023-10-10 13:27:15.320               NaN       NaN       NaN
# 25  2023-10-10 15:56:06.110  Andor/Position 1  0.005572  0.001023
# 27  2023-10-10 15:56:18.950  Andor/Position 1  0.005704  0.000904
# 29  2023-10-10 15:56:31.900  Andor/Position 1  0.006009  0.000845
#
#       AtomNumber       Xcenter        Xwidth   AtomNumberX  IterationNum  \
# 2            NaN           NaN           NaN           NaN           0.0
# 5            NaN           NaN           NaN           NaN           1.0
# 25  4.395981e+06  3.708893e+06  1.219154e+06  2.600261e+15           1.0
# 27  3.635127e+06  3.272270e+00  5.521562e-02  1.215044e+06           3.0
# 29  2.975474e+06  2.174602e-02  4.996874e-06  1.381320e+04           5.0
#
#     IterationCount  ...  VerticalBiasCurrent  ZSBiasVoltage  CamBiasVoltage  \
# 2              1.0  ...                  0.0           1.44           0.322
# 5              2.0  ...                  0.0           1.44           0.322
# 25             6.0  ...                  0.0           1.44           0.322
# 27             6.0  ...                  0.0           1.44           0.322
# 29             6.0  ...                  0.0           1.44           0.322
#
#     VerticalBiasVoltage  HighServo1  LowServo1  D1Time_ms  ODT_Position  \
# 2                 0.377         2.2        0.0        1.5           9.0
# 5                 0.377         2.2        0.0        1.5           9.0
# 25                0.377         2.2        0.0        1.5           1.0
# 27                0.377         2.2        0.0        1.5           1.0
# 29                0.377         2.2        0.0        1.5           1.0
#
#     Var_27  Var_28
# 2      NaN     NaN
# 5      NaN     NaN
# 25     0.0     0.0
# 27     0.0     0.0
# 29     0.0     0.0
#
# [5 rows x 35 columns]

# %%
colum

# %%
ImageAnalysisCode.PlotFromDataCSV?

# %%
df = pd.read_csv(r'Z:\ats317group\Data\2023\09-2023\29 Sep 2023\Data Folder 5-9.csv')

# %%
dfwait30 = df[df.wait==30]

# %%
dataFrame = dfwait30
iterateVariableName = 'VerticalBiasCurrent'
xVariable = 'Ycenter'
yVariable = 'AtomNumber'
groupby = None

iterateVariable = dataFrame[iterateVariableName]
iterateVariable = iterateVariable.unique()

# %%
def PlotFromDataCSV(filePath, xVariable, yVariable, 
                    groupby=None, groupbyX=None, iterateVariable=None, 
                    filterlist=None, filterLogic='and'):
    
    if not os.path.exists(filePath):
        raise FileNotFoundError("The file does not exist!")
    
    df = pd.read_csv(filePath)
    
    if filterlist:
        masklist = []
        for fil in filterlist:
            masklist.append(eval( 'df.' + fil.replace(' ', '_') ))
            
        if len(masklist) > 1:
            for mask in masklist[1:]:
                if filterLogic == 'and':
                    masklist[0] &= mask
                elif filterLogic == 'or':
                    masklist[0] |= mask
        df = df[ masklist[0] ]
    
    columnlist = [xVariable, yVariable]
    
    if iterateVariable:
        iterateVariable.replace(' ', '_')
        iterable = df[iterateVariable].unique()
        columnlist.append(iterateVariable)
    else:
        iterable = [None]
    
    if groupby == xVariable:
        groupbyX = 1
        
    if groupby and not groupbyX:
        groupby.replace(' ', '_')
        columnlist.append(groupby)    
    
    fig, ax = plt.subplots(figsize=(8,5))
    for ii in iterable:
        if ii is None:
            dfii = df[columnlist]
        else:
            dfii = df[columnlist][ (df[iterateVariable]==ii) ]
            
        if groupbyX:
            dfiimean = dfii.groupby(xVariable).mean()
            dfiistd = dfii.groupby(xVariable).std()
            plt.errorbar(dfiimean.index, dfiimean[yVariable],
                         dfiistd[yVariable], capsize=3,
                         label = '{} = {}'.format(iterateVariable, ii))
            plt.scatter(dfiimean.index, dfiimean[yVariable], s=8)
        elif groupby:
            dfiimean = dfii.groupby(groupby).mean()
            dfiistd = dfii.groupby(groupby).std()
            plt.errorbar(dfiimean[xVariable], dfiimean[yVariable],
                         dfiistd[yVariable], dfiistd[xVariable], capsize=3,
                         label = '{} = {}'.format(iterateVariable, ii))        
        else:
            plt.plot( dfii[xVariable], dfii[yVariable], '.', 
                     label = '{} = {}'.format(iterateVariable, ii))
    
    ax.set(xlabel=xVariable, ylabel=yVariable)
    ax.ticklabel_format(axis='both', style='sci', scilimits=(-3,3))

    fig.tight_layout()
    if iterateVariable:
        plt.legend()
    plt.show()
    
    return fig, ax

# %%
path = 'Z:\\ats317group\\Data\\2023/09-2023/29 Sep 2023\\Data Folder 5-9_Calculated on 1019.csv'
fig, ax = PlotFromDataCSV(path, 'Ycenter', 'AtomNumber', filterlist=['wait==30'], 
                iterateVariable='VerticalBiasCurrent', groupby='ODT_Position')

# %%
path = 'Z:\\ats317group\\Data\\2023/09-2023/29 Sep 2023\\Data Folder 5-9.csv'
PlotFromDataCSV(path, 'Ycenter', 'AtomNumber', filterlist=['Ywidth<0.00006', 'wait==30'], 
                iterateVariable='VerticalBiasCurrent', groupby='ODT_Position')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
#                         time                Folder   Ycenter    Ywidth  \
# 6    2023-09-29 14:42:38.060  Andor/ODT position 5  0.005941  0.000032
# 7    2023-09-29 14:42:44.400  Andor/ODT position 5  0.005941  0.000035
# 8    2023-09-29 14:42:50.940  Andor/ODT position 5  0.005942  0.000034
# 9    2023-09-29 14:42:57.360  Andor/ODT position 5  0.005940  0.000034
# 10   2023-09-29 14:43:03.700  Andor/ODT position 5  0.005940  0.000039
# ..                       ...                   ...       ...       ...
# 130  2023-09-29 15:51:52.120  Andor/ODT position 9  0.006624  0.000032
# 137  2023-09-29 15:52:36.410  Andor/ODT position 9  0.006625  0.000022
# 138  2023-09-29 15:52:42.730  Andor/ODT position 9  0.006625  0.000029
# 139  2023-09-29 15:52:49.070  Andor/ODT position 9  0.006623  0.000035
# 140  2023-09-29 15:52:55.390  Andor/ODT position 9  0.006623  0.000035
#
#         AtomNumber   Xcenter        Xwidth    AtomNumberX  IterationNum  \
# 6    382163.016545  0.006425  1.780230e-04   44868.847209           5.0
# 7    667654.764206  0.006393  1.784179e-04   87323.446073           6.0
# 8    506448.536238  0.006398  1.829580e-04   91125.141089           7.0
# 9    253945.244974  0.004286  1.447648e-03  311621.166996           8.0
# 10    92345.898805  0.005278  4.554724e-07      34.018114           9.0
# ..             ...       ...           ...            ...           ...
# 130  483184.929170  0.006293  1.760816e-04  112382.066963          19.0
# 137   20596.159677 -0.001687  4.083835e-03   94555.519187          26.0
# 138   39795.737906  0.011148  4.681665e-05    5496.461307          27.0
# 139  155893.462475  0.011454  2.059002e-04   19590.802186          28.0
# 140  536479.258102  0.006263  1.634071e-04  102915.601187          29.0
#
#      IterationCount  ...  ZSBiasCurrent  CamBiasCurrent  VerticalBiasCurrent  \
# 6              10.0  ...            6.0             0.0                  0.0
# 7              10.0  ...            5.4             0.0                  2.0
# 8              10.0  ...            5.0             0.0                  3.0
# 9              10.0  ...            4.9             0.0                  4.0
# 10             10.0  ...            4.7             0.0                  5.0
# ..              ...  ...            ...             ...                  ...
# 130            30.0  ...            4.7             0.0                  5.0
# 137            30.0  ...            5.4             0.0                  2.0
# 138            30.0  ...            5.0             0.0                  3.0
# 139            30.0  ...            4.9             0.0                  4.0
# 140            30.0  ...            4.7             0.0                  5.0
#
#      ZSBiasVoltage  CamBiasVoltage  VerticalBiasVoltage  HighServo1  \
# 6            1.440           0.322                0.377         2.2
# 7            1.332           0.322                0.739         2.2
# 8            1.260           0.322                0.920         2.2
# 9            1.242           0.322                1.101         2.2
# 10           1.206           0.322                1.282         2.2
# ..             ...             ...                  ...         ...
# 130          1.206           0.322                1.282         2.2
# 137          1.332           0.322                0.739         2.2
# 138          1.260           0.322                0.920         2.2
# 139          1.242           0.322                1.101         2.2
# 140          1.206           0.322                1.282         2.2
#
#      LowServo1  D1Time_ms  ODT_Position
# 6          0.0        1.5           5.0
# 7          0.0        1.5           5.0
# 8          0.0        1.5           5.0
# 9          0.0        1.5           5.0
# 10         0.0        1.5           5.0
# ..         ...        ...           ...
# 130        0.0        1.5           9.0
# 137        0.0        1.5           9.0
# 138        0.0        1.5           9.0
# 139        0.0        1.5           9.0
# 140        0.0        1.5           9.0
#
# [62 rows x 33 columns]

# %%
path = 'Z:\\ats317group\\Data\\2023/09-2023/29 Sep 2023\\Data Folder 5-9.csv'
fig, ax = PlotFromDataCSV(path, 'Ycenter', 'AtomNumber', filterlist=['Ywidth<0.00006', 'wait==30'], 
                iterateVariable='VerticalBiasCurrent', groupby='ODT_Position')
ax.set_xlabel('Y Center (m)')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# Text(0.5, 17.200000000000003, 'Y Center (m)')

# %%
fig

# %%
fig, ax = plt.subplots(figsize=(10,8))

for ii in (iterateVariable):
        
    if groupby:
        dfSelect = dfwait30[ (dfwait30.VerticalBiasCurrent==ii) & (dfwait30.Ywidth < 0.00006) ][[xVariable, yVariable, groupby]]
        dfmean = dfSelect.groupby(groupby).mean()
        dfstd = dfSelect.groupby(groupby).std()
        plt.errorbar( dfmean[xVariable], dfmean[yVariable], 
                     dfstd[yVariable], dfstd[xVariable], capsize=3, 
                     label = '{} = {}'.format(iterateVariableName, ii))
    else:
        dfSelect = dfwait30[ (dfwait30.VerticalBiasCurrent==ii) & (dfwait30.Ywidth < 0.00006) ][[xVariable, yVariable]]
        plt.plot( dfSelect[xVariable], dfSelect[yVariable], '.', label = '{} = {}'.format(iterateVariableName, ii))
    
plt.legend()
ax.set(xlabel=xVariable, ylabel=yVariable)
# Out:
# [Text(0.5, 0, 'Ycenter'), Text(0, 0.5, 'AtomNumber')]

# %%
xx, yy = df99.columns.values, df99.index.values
zz99 = df99.values
zz11 = df11.values
XX,YY = np.meshgrid(xx,yy)

fig, ax = plt.subplots(figsize=[10,10], subplot_kw=dict(projection='3d'))
zz = np.divide(zz11,zz99)

ax.plot_surface(XX, YY ,zz)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SOMMER~1\AppData\Local\Temp/ipykernel_4888/3856562325.py in <module>
#       7 zz = np.divide(zz11,zz99)
#       8
# ----> 9 ax.plot_surface(XX, YY ,zz)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1664             # a list with None entries, that is discarded later.
#    1665             for p, col in itertools.zip_longest(polys, colset):
# -> 1666                 new_poly = np.array(p)[~np.isnan(p).any(axis=1)]
#    1667                 if len(new_poly):
#    1668                     new_polys.append(new_poly)
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
