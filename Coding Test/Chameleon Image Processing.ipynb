# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
cd ..
# Out:
# C:\Users\Sommer Lab\Documents\Analysis Code

# %%
import sys
# sys.path.append(r'C:\Users\Sommer Lab\Documents\Analysis Code')
import os
from scipy.optimize import curve_fit
from scipy.ndimage import rotate
from scipy.integrate import simpson

from scipy import ndimage as ni
from skimage.filters import threshold_otsu

from ImageAnalysis import ImageAnalysisCode
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime

# %%
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams["image.cmap"] = "jet"

# %%
imgs = np.load(r'D:\Dropbox (Lehigh University)\Sommer Lab Shared\Data\2024\02-2024\23 Feb 2024\Top Images from Test.npy')

# %%
plt.imshow(imgs[1], cmap='jet')

# %%
img1 = ni.gaussian_filter(imgs[1], 3)
plt.imshow(img1, cmap='jet')

# %%
img2 = ni.median_filter(imgs[1], 5)

# %%
plt.imshow(img2)

# %%
img3 = ni.gaussian_filter(img1, 3)
plt.imshow(img3, cmap='jet')

# %%
thr = threshold_otsu(img1)
thr
# Out:
# 746034836615.507

# %%
plt.imshow(img1<thr, interpolation='nearest')
plt.colorbar()
