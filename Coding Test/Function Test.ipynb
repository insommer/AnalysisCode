# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import PIL
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
cd ..
# Out:
# /home/idies/workspace/Storage/lianmign/persistent/UCA_Coding_Test/AnalysisCode

# %%
from ImageAnalysis import ImageAnalysisCode
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 from ImageAnalysis import ImageAnalysisCode
#
# File ~/workspace/Storage/lianmign/persistent/UCA_Coding_Test/AnalysisCode/ImageAnalysis/ImageAnalysisCode.py:31
#      29 from mpl_toolkits.axes_grid1 import make_axes_locatable
#      30 import pickle
# ---> 31 import warning
#      33 from ImageAnalysis.ExperimentParameters import ExperimentParams
#      36 def GetDataLocation(date, DataPath='D:\Dropbox (Lehigh University)\Sommer Lab Shared\Data'):
#
# ModuleNotFoundError: No module named 'warning'

# %%
pwd

# %%
run 'Applications/analyze chameleon binary.py'
# Out:
# /home/idies/workspace/Storage/lianmign/persistent/UCA_Coding_Test/AnalysisCode/Applications/analyze chameleon binary.py:85: DeprecationWarning: GetDataLocation will be replaced with GetDayFolder(date, root= )
#   dataLocation = ImageAnalysisCode.GetDataLocation(date, DataPath=data_path)
# Warning! The log is 0.02 s earlier than the data file, potential mismatching!
# Picked the logfile earlier, the time interval is 0.03 s
# Warning! The log is 0.33 s earlier than the data file, potential mismatching!
# Picked the logfile earlier, the time interval is 0.34 s
# Warning! The log is 0.83 s earlier than the data file, potential mismatching!
# Picked the logfile earlier, the time interval is 0.83 s
# Warning! The log is 0.43 s earlier than the data file, potential mismatching!
# Picked the logfile earlier, the time interval is 0.43 s
# Warning! The log is 0.91 s earlier than the data file, potential mismatching!
# Picked the logfile earlier, the time interval is 0.92 s
# Warning! The log is 0.56 s earlier than the data file, potential mismatching!
# Picked the logfile earlier, the time interval is 0.57 s
# Finish calculating columnDensities.
# column_density_xylim = (450, 900, 300, 750)
# Center x: 1070.6354106201973
# Center y: 1032.6531238718544
# Number of atoms:0e6
# column_density_xylim = (450, 900, 300, 750)
# Center x: 1414.6892135673884
# Center y: 1125.1725348648908
# Number of atoms:0e6
# difference in center x: 344.0538029471911
# difference in center y: 92.51941099303644
# column_density_xylim = (450, 900, 300, 750)
# Center x: 1076.4667084998212
# Center y: 1035.9406708264562
# Number of atoms:0e6
# column_density_xylim = (450, 900, 300, 750)
# Center x: 1071.4482254947438
# Center y: 1030.5418311585295
# Number of atoms:0e6
# difference in center x: -5.018483005077314
# difference in center y: -5.3988396679267225
# column_density_xylim = (450, 900, 300, 750)
# Center x: 1419.3157091891337
# Center y: 1134.1273434011098
# Number of atoms:0e6
# column_density_xylim = (450, 900, 300, 750)
# Center x: 1405.8602425611339
# Center y: 1129.7952471305819
# Number of atoms:0e6
# difference in center x: -13.45546662799984
# difference in center y: -4.332096270527927

# %%
run 'Applications/Analyze_Atom_Pictures.py'
# Out:
# subtract burntin	 0
# skip firstImg		 1
# picture/iteration	 4
# first frame			 1
# Loading pictures: |
# Finish loading pictures, 12 raw images loaded.
# Finish calculating opticalDensity.
# Fitting y data: |
# Fitting x data: |
# Finish fitting data.
# subtract burntin	 0
# skip firstImg		 0
# picture/iteration	 3
# first frame			 0
# Finish calculating opticalDensity.
# Fitting y data: |
# Fitting x data: |
# Finish fitting data.
# ====================
# wait        1.0
# fmod_kHz    5.0
# Name: 2024-11-11 15:26:20.877048, dtype: object
# ====================
# ====================
# wait        50.0
# fmod_kHz     5.0
# Name: 2024-11-11 15:26:33.653519, dtype: object
# ====================
# ====================
# wait        100.0
# fmod_kHz      5.0
# Name: 2024-11-11 15:26:46.547306, dtype: object
# ====================
# ====================
#                             wait  fmod_kHz
# time
# 2024-11-14 19:15:07.404158   5.0       5.0
# 2024-11-14 19:15:07.404158   5.0       5.0
# 2024-11-14 19:15:07.404158   5.0       5.0
# ====================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/workspace/Storage/lianmign/persistent/UCA_Coding_Test/AnalysisCode/Applications/Analyze_Atom_Pictures.py:188
#     185 textVA = 'bottom'
#     187 if intermediatePlot:
# --> 188     ImageAnalysisCode.plotImgAndFitResult(OD[cam]/runParams[cam].expmntParams.cross_section,
#     189                                           fits[cam][0], bgs=fits[cam][1],
#     190                                           dx=runParams[cam].dx_micron,
#     191                                           imgs2=OD[cam],
#     192                                             # filterLists=[['LowServo1==0.5']],
#     193                                            plotRate=plotRate, plotPWindow=plotPWindow,
#     194                                             variablesToDisplay = variablesToDisplay,
#     195                                            showTimestamp=showTimestamp,
#     196                                           variableLog=varLog[cam],
#     197                                           logTime=varLog[cam].index,
#     198                                           uniformscale=uniformscale,
#     199                                           textLocationY=0.9, rcParams=rcParams,
#     200                                           figSizeRate=1,
#     201                                           sharey=False
#     202                                          )
#
# File ~/workspace/Storage/lianmign/persistent/UCA_Coding_Test/AnalysisCode/ImageAnalysis/ImageAnalysisCode.py:2380, in plotImgAndFitResult(imgs, popts, bgs, imgs2, filterLists, fitFunc, axlist, dx, plotRate, plotPWindow, figSizeRate, fontSizeRate, uniformscale, addColorbar, variableLog, variablesToDisplay, logTime, showTimestamp, textLocationY, textVA, xlabel, ylabel, title, sharex, sharey, rcParams)
#    2376 print(variableLog.loc[logTime[ind]][variablesToDisplay])
#    2377 print('='*20)
#    2379 axes[plotInd,0].text(-0.05, textLocationY,
# -> 2380                 variableLog.loc[logTime[ind]][variablesToDisplay].to_string(name=showTimestamp).replace('Name','Time'),
#    2381                 fontsize=5*fontSizeRate, ha='left', va=textVA, transform=axes[plotInd,0].transAxes,
#    2382                 bbox=dict(boxstyle="square", ec=(0,0,0), fc=(1,1,1), alpha=0.7))
#
# TypeError: to_string() got an unexpected keyword argument 'name'

# %%
varLog[cam][variablesToDisplay]
# Out:
#                             wait  fmod_kHz
# time
# 2024-11-14 19:15:07.404158   5.0       5.0
# 2024-11-14 19:15:07.404158   5.0       5.0
# 2024-11-14 19:15:07.404158   5.0       5.0

# %%
print(varLog[cam].iloc[0][variablesToDisplay])
# Out:
# wait        5.0
# fmod_kHz    5.0
# Name: 2024-11-14 19:15:07.404158, dtype: object

# %%
varLog[cam].index
# Out:
# DatetimeIndex(['2024-11-14 19:15:07.404158', '2024-11-14 19:15:07.404158',
#                '2024-11-14 19:15:07.404158'],
#               dtype='datetime64[ns]', name='time', freq=None)

# %%
run 'Applications/Analyze Zyla_Mar2024.py'
# Out:
# /home/idies/workspace/Storage/lianmign/persistent/UCA_Coding_Test/AnalysisCode/Applications/Analyze Zyla_Mar2024.py:96: DeprecationWarning: GetDataLocation will be replaced with GetDayFolder(date, root= )
#   ####################################
# subtract burntin	 0
# skip firstImg		 1
# picture/iteration	 4
# first frame			 1
# Loading pictures: |
# Finish loading pictures, 12 raw images loaded.
# Finish calculating opticalDensity.
# Fitting y data: |
# Fitting x data: |
# Finish fitting data.
